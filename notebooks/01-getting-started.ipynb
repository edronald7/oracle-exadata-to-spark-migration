# %% [markdown]
# # 🚀 Getting Started: Oracle Exadata → Apache Spark
#
# Este notebook te guía a través de tu primera migración de SQL Oracle a Spark.
#
# **Objetivos**:
# 1. Generar datos de prueba
# 2. Ejecutar query Oracle (comentado)
# 3. Comparar 3 enfoques Spark: SQL, PySpark DataFrame
# 4. Validar resultados
#
# **Prerequisitos**:
# - PySpark 3.5+ instalado
# - Jupyter notebook o Databricks
# - 10 minutos de tu tiempo
